# %% [markdown]
# # Práctica - Unidad 2
# **Modelos de visión y aplicaciones**
#
# > Imagenes:
# > * https://upload.wikimedia.org/wikipedia/commons/3/3f/Arc_Triomf_31-10-13.JPG
# > * https://i.pinimg.com/736x/c9/cb/78/c9cb78a86232453c39df9ef5716278b4.jpg
# > * https://raw.githubusercontent.com/jpmanson/tuia-unr/main/images/blox.jpg
# > * https://www.fuenterrebollo.com/Heraldica-Piedra/Europa-Viaje/Belgica/Bruselas/atomo-1.jpg
# > * https://raw.githubusercontent.com/jpmanson/tuia-unr/main/images/leaf.jpg
# >
# > Videos:
# > * https://raw.githubusercontent.com/jpmanson/tuia-unr/main/videos/traffic_720p.mp4

# %% [markdown]
# # 1. Feature detection and matching

# %% [markdown]
# ## Ejercicio 1: Detección y Visualización de Keypoints

# %% [markdown]
# ### Parte A - Comparación de Detectores

# %% [markdown]
# #### 1. Descarga dos imágenes de monumentos arquitectónicos diferentes (pueden usar las del ejemplo o buscar otras)

# %% [markdown]
# #### 2. Implementa la detección de keypoints usando:
# * ORB (500 keypoints máximo)
# * SIFT (500 keypoints máximo)
# * FAST

# %% [markdown]
# #### 3. Para cada detector, visualiza y cuenta:
# * Número total de keypoints detectados
# * Distribución de los keypoints en la imagen (¿se concentran en alguna zona?)

# %% [markdown]
# #### 4. Crea una tabla comparativa con los tiempos de ejecución de cada método

# %% [markdown]
# ### Parte B - Análisis de Invarianza

# %% [markdown]
# #### 1. Toma una imagen y créale tres variaciones:
# * Rotada 45 grados
# * Escalada al 50%
# * Con cambio de brillo (+30%)

# %% [markdown]
# #### 2. Aplica SIFT a todas las versiones y analiza qué porcentaje de keypoints se mantiene

# %% [markdown]
# ## Ejercicio 2: Detección de Esquinas con Shi-Tomasi

# %% [markdown]
# #### 1. Experimenta con diferentes valores de parámetros:
# * maxCorners: [10, 25, 50, 100]
# * qualityLevel: [0.001, 0.01, 0.1]
# * minDistance: [5, 10, 20]

# %% [markdown]
# #### 2. Documenta cómo cada parámetro afecta la detección

# %% [markdown]
# #### 3. Encuentra la combinación óptima para detectar exactamente las esquinas de los bloques

# %% [markdown]
# ## Ejercicio 3: Detección de Crestas (Ridges)

# %% [markdown]
# #### 1. Aplica 4 filtros: Hessian, Meijering, Sato y Frangi
# #### 2. Para cada filtro:
# * Prueba con sigmas=range(2, 10, 2) y sigmas=range(1, 5, 1)
# * Determina cuál sigma funciona mejor para tu imagen

# %% [markdown]
# #### 3. Combina los resultados de dos filtros para mejorar la detección

# %% [markdown]
# ## Ejercicio 4: Matching de Características - Búsqueda de Objetos

# %% [markdown]
# ### Parte A - Matching Básico

# %% [markdown]
# #### 1. Toma una foto de un objeto pequeño (ej: libro, taza, celular)
# #### 2. Toma otra foto de una escena que contenga ese objeto entre otros

# %% [markdown]
# #### 3. Implementa:
# * ORB con BFMatcher
# * Filtra los matches por distancia < 0.7 * max_distance
# * Dibuja solo los mejores 20 matches

# %% [markdown]
# 4. Calcula el porcentaje de matches correctos vs incorrectos

# %% [markdown]
# ### Parte B - Comparación de Métodos

# %% [markdown]
# #### 1. Repite el ejercicio anterior usando:
# * SIFT + FLANN (con ratio test de Lowe)
# * ORB + BFMatcher

# %% [markdown]
# #### Compara:
# * Precisión de los matches
# * Tiempo de ejecución
# * Robustez ante cambios de escala
